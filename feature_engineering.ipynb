# %% [markdown]
# # Feature Engineering
# This notebook generates new features and applies scaling to the cleaned rental listings dataset.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# %% [markdown]
# ## 2. Load Final Cleaned Data

# %%
df = pd.read_csv('final_cleaned_listings.csv')
display(df.head())
# Out:
#                                                title   price         location  \
# 0  ADV905*4BHK Villa for rent in Madinat Illam in...   750.0   Qurum, Muscat•
# 1    ADV906**4BHK Villa in a comples in shatti qurum  1900.0   Qurum, Muscat•
# 2  ADC507*** Office Space in Azaiba – 440 sqm for...  2310.0  Azaiba, Muscat•
# 3  *ADV705** 3+1 BHK Villa for Rent in Bousher –A...   650.0  Bosher, Muscat•
# 4  4 BR + Maid’s Room Spacious Well-Designed Vill...   750.0  Azaiba, Muscat•
#
#     area  bathrooms  bedrooms  price_per_sqm
# 0  300.0        4.0       4.0       2.500000
# 1  300.0        4.0       4.0       6.333333
# 2  440.0        2.0       2.0       5.250000
# 3  350.0        4.0       3.0       1.857143
# 4  439.0        5.0       4.0       1.708428

# %% [markdown]
# ## 3. Generate New Features

# %%
# Price per square meter
df['price_per_sqm'] = df['price'] / df['area']
# Total rooms (bedrooms + bathrooms)
df['total_rooms'] = df['bedrooms'] + df['bathrooms']
# Extract district from location (text before comma)
df['district'] = df['location'].apply(lambda x: x.split(',')[0] if isinstance(x, str) else x)
display(df[['price_per_sqm','total_rooms','district']].head())
# Out:
#    price_per_sqm  total_rooms district
# 0       2.500000          8.0    Qurum
# 1       6.333333          8.0    Qurum
# 2       5.250000          4.0   Azaiba
# 3       1.857143          7.0   Bosher
# 4       1.708428          9.0   Azaiba

# %% [markdown]
# ## 4. Encode Categorical Feature

# %%
# Label encode the 'district' feature
le = LabelEncoder()
df['district_encoded'] = le.fit_transform(df['district'])
display(df[['district','district_encoded']].head())
# Out:
#   district  district_encoded
# 0    Qurum                66
# 1    Qurum                66
# 2   Azaiba                30
# 3   Bosher                39
# 4   Azaiba                30

# %% [markdown]
# ## 5. Apply Feature Scaling

# %%
# Select numeric features to scale
numeric_features = ['price','area','price_per_sqm','total_rooms']

# Min-Max scaling
mm_scaler = MinMaxScaler()
df_mm = df.copy()
df_mm[numeric_features] = mm_scaler.fit_transform(df_mm[numeric_features])
print('Min-Max Scaled Sample:')
display(df_mm.head())

# Standard scaling
ss_scaler = StandardScaler()
df_ss = df.copy()
df_ss[numeric_features] = ss_scaler.fit_transform(df_ss[numeric_features])
print('Standard Scaled Sample:')
display(df_ss.head())
# Out:
# Min-Max Scaled Sample:
#                                                title    price  \
# 0  ADV905*4BHK Villa for rent in Madinat Illam in...  0.00149
# 1    ADV906**4BHK Villa in a comples in shatti qurum  0.00379
# 2  ADC507*** Office Space in Azaiba – 440 sqm for...  0.00461
# 3  *ADV705** 3+1 BHK Villa for Rent in Bousher –A...  0.00129
# 4  4 BR + Maid’s Room Spacious Well-Designed Vill...  0.00149
#
#           location     area  bathrooms  bedrooms  price_per_sqm  total_rooms  \
# 0   Qurum, Muscat•  0.00296        4.0       4.0       0.049872     0.304348
# 1   Qurum, Muscat•  0.00296        4.0       4.0       0.126549     0.304348
# 2  Azaiba, Muscat•  0.00436        2.0       2.0       0.104879     0.130435
# 3  Bosher, Muscat•  0.00346        4.0       3.0       0.037013     0.260870
# 4  Azaiba, Muscat•  0.00435        5.0       4.0       0.034038     0.347826
#
#   district  district_encoded
# 0    Qurum                66
# 1    Qurum                66
# 2   Azaiba                30
# 3   Bosher                39
# 4   Azaiba                30
# Standard Scaled Sample:
#                                                title     price  \
# 0  ADV905*4BHK Villa for rent in Madinat Illam in...  0.001911
# 1    ADV906**4BHK Villa in a comples in shatti qurum  0.137008
# 2  ADC507*** Office Space in Azaiba – 440 sqm for...  0.185173
# 3  *ADV705** 3+1 BHK Villa for Rent in Bousher –A... -0.009836
# 4  4 BR + Maid’s Room Spacious Well-Designed Vill...  0.001911
#
#           location      area  bathrooms  bedrooms  price_per_sqm  total_rooms  \
# 0   Qurum, Muscat• -0.029129        4.0       4.0      -0.261340     0.852294
# 1   Qurum, Muscat• -0.029129        4.0       4.0       0.516717     0.852294
# 2  Azaiba, Muscat•  0.038050        2.0       2.0       0.296831    -0.346388
# 3  Bosher, Muscat• -0.005137        4.0       3.0      -0.391822     0.552624
# 4  Azaiba, Muscat•  0.037570        5.0       4.0      -0.422007     1.151965
#
#   district  district_encoded
# 0    Qurum                66
# 1    Qurum                66
# 2   Azaiba                30
# 3   Bosher                39
# 4   Azaiba                30

# %% [markdown]
# ## 6. Save Engineered Dataset

# %%
# Save the dataset with new features
df.to_csv('engineered_listings.csv', index=False)
print('Engineered dataset saved to engineered_listings.csv')
# Out:
# Engineered dataset saved to engineered_listings.csv
